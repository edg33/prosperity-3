# %%
path = "/Users/evangray/Desktop/Projects/prosperity/prosperity-3/Data Logs/Round 1/"

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# Kelp MA RESIN MR
# log_path = "/Users/evangray/Desktop/Projects/prosperity/prosperity-3/Data Logs/Round 1/09125e0c-c6ff-4960-a771-9098bd41488b.csv"
# Tutorial 3
# log_path = "/Users/evangray/Desktop/Projects/prosperity/prosperity-3/Data Logs/Round 1/50ad9b64-ef81-4d30-9b8d-740b6eb5500f.csv"
# Kelp MR testing
log_path = "/Users/evangray/Desktop/Projects/prosperity/prosperity-3/Data Logs/Round 1/72411999-80f8-4b3e-bddf-d344213dfd1f.csv"
# 1k
# log_path = "/Users/evangray/Desktop/Projects/prosperity/prosperity-3/Data Logs/Round 1/81cfb15d-90f1-4905-8c95-d31b696c64d3.csv"
df = pd.read_csv(log_path, delimiter =";")
df
# Out:
#       day  timestamp           product  bid_price_1  bid_volume_1  \
# 0       0          0  RAINFOREST_RESIN         9998             9
# 1       0          0              KELP         2028            23
# 2       0          0         SQUID_INK         1968            23
# 3       0        100         SQUID_INK         1970             1
# 4       0        100              KELP         2031             1
# ...   ...        ...               ...          ...           ...
# 2995    0      99800              KELP         2028            26
# 2996    0      99800         SQUID_INK         1967            26
# 2997    0      99900              KELP         2028            27
# 2998    0      99900         SQUID_INK         1967            27
# 2999    0      99900  RAINFOREST_RESIN         9998             6
#
#       bid_price_2  bid_volume_2  bid_price_3  bid_volume_3  ask_price_1  \
# 0          9995.0          23.0          NaN           NaN        10005
# ...

# %%
squid_df = df[df["product"] == "SQUID_INK"].reset_index()
kelp_df = df[df["product"] == "KELP"].reset_index()
resin_df = df[df["product"] == "RAINFOREST_RESIN"].reset_index()

# %%
resin_df
# Calculate average up to point
resin_df['mid_price_avg'] = resin_df['mid_price'].expanding().mean().shift(1)

# %%
activities
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 activities
#
# NameError: name 'activities' is not defined

# %%
prices = [col for col in resin_df.columns if "price" in col]
for price in prices:
    print(f"{price}: {np.nanmin(resin_df[price])}")
    print(f"{price}: {np.nanmax(resin_df[price])}")
    print()
# Out:
# bid_price_1: 9995
# bid_price_1: 10002
#
# bid_price_2: 9995.0
# bid_price_2: 10000.0
#
# bid_price_3: 9995.0
# bid_price_3: 9998.0
#
# ask_price_1: 9998
# ask_price_1: 10005
#
# ask_price_2: 10000.0
# ask_price_2: 10005.0
#
# ask_price_3: 10004.0
# ask_price_3: 10005.0
#
# mid_price: 9996.5
# mid_price: 10003.5
#
# mid_price_avg: 9999.847826086956
# mid_price_avg: 10002.25

# %%
kelp_df
# Out:
#      index  day  timestamp product  bid_price_1  bid_volume_1  bid_price_2  \
# 0        2    1          0    KELP         2032            23          NaN
# 1        3    1        100    KELP         2034             1       2033.0
# 2        7    1        200    KELP         2032            22          NaN
# 3        9    1        300    KELP         2034             1       2032.0
# 4       14    1        400    KELP         2032            28          NaN
# ..     ...  ...        ...     ...          ...           ...          ...
# 995   2986    1      99500    KELP         2034            20          NaN
# 996   2989    1      99600    KELP         2034            28          NaN
# 997   2991    1      99700    KELP         2034            26          NaN
# 998   2994    1      99800    KELP         2034            26          NaN
# 999   2999    1      99900    KELP         2034            27          NaN
#
# ...

# %%
window_lengths = [3, 5, 10, 20, 30, 50, 100, 200]

# Assuming kelp_df is your existing DataFrame with a 'mid_price' column.
# Loop over each window length and compute the moving average.
diff = pd.DataFrame()
diff["mid_price"] = kelp_df["mid_price"] - squid_df["mid_price"]
for window in window_lengths:
    # Create a new column for each moving average; the new column name will indicate the window size.
    kelp_df[f'ma_{window}'] = kelp_df['mid_price'].rolling(window=window).mean()
    squid_df[f'ma_{window}'] = squid_df['mid_price'].rolling(window=window).mean()
    diff[f'ma_{window}'] = diff['mid_price'].rolling(window=window).mean()

# %%
plt.figure(figsize=(15, 8))
# plt.plot(kelp_df['mid_price'], label='mid_price', linewidth=2)

test_lengths = [30, 50]

for window in test_lengths:
    plt.plot(kelp_df[f'ma_{window}'], label=f'MA {window}')

plt.title('Moving Averages of mid_price (Kelp)')
plt.xlabel('Index')
plt.ylabel('mid_price')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(15, 8))
# plt.plot(kelp_df['mid_price'], label='mid_price', linewidth=2)
window_lengths = [3, 5, 10, 20, 30, 50, 100, 200]
test_lengths = [10, 100]

for window in test_lengths:
    plt.plot(squid_df[f'ma_{window}'], label=f'MA {window}')

plt.title('Moving Averages of mid_price (Squid)')
plt.xlabel('Index')
plt.ylabel('mid_price')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
plt.plot(kelp_df["mid_price"] - squid_df["mid_price"])
plt.title("Kelp Price - Squid Price")
# Out:
# Text(0.5, 1.0, 'Kelp Price - Squid Price')

# %%
plt.plot(squid_df["mid_price"])
plt.title("Squid Price")
# Out:
# Text(0.5, 1.0, 'Squid Price')

# %%
plt.figure(figsize=(15, 8))
# plt.plot(kelp_df['mid_price'], label='mid_price', linewidth=2)
window_lengths = [3, 5, 10, 20, 30, 50, 100, 200]
test_lengths = [10, 30]

for window in window_lengths:
    plt.plot(diff[f'ma_{window}'], label=f'MA {window}')

plt.title('Moving Averages of mid_price (Squid)')
plt.xlabel('Index')
plt.ylabel('mid_price')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
containers = [
    (10,1),
    (80,6),
    (37,3),
    (17,1),
    (31,2),
    (90,10),
    (50,4),
    (20,2),
    (73,4),
    (89,8)
]

containers_without = []
for container in containers:
    calc = (container[0] * 10000) / container[1]
    containers_without.append(calc)

containers_with = []
for container in containers:
    calc = (container[0] * 10000) / (container[1] + 1)
    containers_with.append(calc)

# %%
for i in containers_without:
    print(i)
# Out:
# 100000.0
# 133333.33333333334
# 123333.33333333333
# 170000.0
# 155000.0
# 90000.0
# 125000.0
# 100000.0
# 182500.0
# 111250.0

# %%
for i in containers_with:
    print(i)
# Out:
# 50000.0
# 114285.71428571429
# 92500.0
# 85000.0
# 103333.33333333333
# 81818.18181818182
# 100000.0
# 66666.66666666667
# 146000.0
# 98888.88888888889

# %%
np.argmax(containers_with)
# Out:
# 8

# %%
list(zip(containers_without, containers_with))
# Out:
# [(100000.0, 50000.0),
#  (133333.33333333334, 114285.71428571429),
#  (123333.33333333333, 92500.0),
#  (170000.0, 85000.0),
#  (155000.0, 103333.33333333333),
#  (90000.0, 81818.18181818182),
#  (125000.0, 100000.0),
#  (100000.0, 66666.66666666667),
#  (182500.0, 146000.0),
#  (111250.0, 98888.88888888889)]

# %%
for i in list(zip(containers_without, containers_with)):
    print(i[0] - i[1])
# Out:
# 50000.0
# 19047.619047619053
# 30833.33333333333
# 85000.0
# 51666.66666666667
# 8181.8181818181765
# 25000.0
# 33333.33333333333
# 36500.0
# 12361.11111111111

# %%
plt.plot(containers_with)
plt.plot(containers_without)
plt.grid()

# %%
import random
import numpy as np

# Setup: (multiplier, inhabitants)
options = [
    (10, 1),
    (80, 6),
    (37, 3),
    (17, 1),
    (31, 2),
    (90, 10),
    (50, 4),
    (20, 2),
    (73, 4),
    (89, 8)
]

B = 1  # Base amount, assumed 1 for simplicity
num_players = 10  # Total number of players, including yourself
num_simulations = 10000

# Track average payoffs
payoffs = np.zeros(len(options))

for my_choice in range(len(options)):
    total_reward = 0

    for _ in range(num_simulations):
        # Other players randomly choose options (excluding you)
        others_choices = [random.randint(0, 9) for _ in range(num_players - 1)]
        # Count how many chose your option
        n_i = others_choices.count(my_choice)
        
        multiplier, inhabitants = options[my_choice]
        # Your utility: base * multiplier divided by (others + you + inhabitants)
        utility = B * multiplier / (n_i + 1 + inhabitants)
        total_reward += utility

    # Average payoff for this choice
    payoffs[my_choice] = total_reward / num_simulations

# Output results
for i, payoff in enumerate(payoffs):
    print(f"Option {i}: Multiplier={options[i][0]}, Inhabitants={options[i][1]}, Expected Payoff={payoff:.2f}")

# Optional: Best option
best = np.argmax(payoffs)
print(f"\nBest option to choose: Option {best} (Multiplier={options[best][0]}, Inhabitants={options[best][1]}) with Expected Payoff={payoffs[best]:.2f}")
# Out:
# Option 0: Multiplier=10, Inhabitants=1, Expected Payoff=3.77
# Option 1: Multiplier=80, Inhabitants=6, Expected Payoff=10.26
# Option 2: Multiplier=37, Inhabitants=3, Expected Payoff=7.77
# Option 3: Multiplier=17, Inhabitants=1, Expected Payoff=6.41
# Option 4: Multiplier=31, Inhabitants=2, Expected Payoff=8.33
# Option 5: Multiplier=90, Inhabitants=10, Expected Payoff=7.61
# Option 6: Multiplier=50, Inhabitants=4, Expected Payoff=8.66
# Option 7: Multiplier=20, Inhabitants=2, Expected Payoff=5.39
# Option 8: Multiplier=73, Inhabitants=4, Expected Payoff=12.65
# Option 9: Multiplier=89, Inhabitants=8, Expected Payoff=9.05
#
# Best option to choose: Option 8 (Multiplier=73, Inhabitants=4) with Expected Payoff=12.65

# %%
import random
import numpy as np

# Setup: (multiplier, inhabitants)
options = [
    (10, 1),
    (80, 6),
    (37, 3),
    (17, 1),
    (31, 2),
    (90, 10),
    (50, 4),
    (20, 2),
    (73, 4),
    (89, 8)
]

B = 1  # Base amount
num_players = 10  # Total number of players (including you)
num_simulations = 10000

# Compute attractiveness scores (multiplier / (inhabitants + 1))
attractiveness = [m / (h + 1) for m, h in options]
total = sum(attractiveness)
weights = [a / total for a in attractiveness]  # Normalize to probabilities

payoffs = np.zeros(len(options))

for my_choice in range(len(options)):
    total_reward = 0

    for _ in range(num_simulations):
        # Simulate other players' choices using weighted probabilities
        others_choices = random.choices(range(len(options)), weights=weights, k=num_players - 1)
        n_i = others_choices.count(my_choice)

        multiplier, inhabitants = options[my_choice]
        utility = B * multiplier / (n_i + 1 + inhabitants)
        total_reward += utility

    payoffs[my_choice] = total_reward / num_simulations

# Output results
for i, payoff in enumerate(payoffs):
    print(f"Option {i}: Multiplier={options[i][0]}, Inhabitants={options[i][1]}, Expected Payoff={payoff:.2f}")

# Best option
best = np.argmax(payoffs)
print(f"\nBest option to choose: Option {best} (Multiplier={options[best][0]}, Inhabitants={options[best][1]}) with Expected Payoff={payoffs[best]:.2f}")
# Out:
# Option 0: Multiplier=10, Inhabitants=1, Expected Payoff=4.27
# Option 1: Multiplier=80, Inhabitants=6, Expected Payoff=10.04
# Option 2: Multiplier=37, Inhabitants=3, Expected Payoff=7.82
# Option 3: Multiplier=17, Inhabitants=1, Expected Payoff=6.56
# Option 4: Multiplier=31, Inhabitants=2, Expected Payoff=8.19
# Option 5: Multiplier=90, Inhabitants=10, Expected Payoff=7.67
# Option 6: Multiplier=50, Inhabitants=4, Expected Payoff=8.58
# Option 7: Multiplier=20, Inhabitants=2, Expected Payoff=5.72
# Option 8: Multiplier=73, Inhabitants=4, Expected Payoff=11.73
# Option 9: Multiplier=89, Inhabitants=8, Expected Payoff=9.02
#
# Best option to choose: Option 8 (Multiplier=73, Inhabitants=4) with Expected Payoff=11.73

# %%
import random
import numpy as np
import matplotlib.pyplot as plt

# Options: (multiplier, inhabitants)
options = [
    (10, 1), (80, 6), (37, 3), (17, 1), (31, 2),
    (90, 10), (50, 4), (20, 2), (73, 4), (89, 8)
]

B = 1
num_players = 10
num_simulations = 10000

# Define weighting schemes
def get_weights(scheme):
    scores = []
    for m, h in options:
        ratio = m / (h + 1)
        if scheme == "uniform":
            scores.append(1)
        elif scheme == "linear":
            scores.append(ratio)
        elif scheme == "quadratic":
            scores.append(ratio**2)
        elif scheme == "exponential":
            scores.append(np.exp(ratio))
    total = sum(scores)
    return [s / total for s in scores]

# Simulate expected payoffs for each weighting scheme
schemes = ["uniform", "linear", "quadratic", "exponential"]
results = {}

for scheme in schemes:
    weights = get_weights(scheme)
    payoffs = np.zeros(len(options))
    
    for my_choice in range(len(options)):
        total_reward = 0
        for _ in range(num_simulations):
            others_choices = random.choices(range(len(options)), weights=weights, k=num_players - 1)
            n_i = others_choices.count(my_choice)
            m, h = options[my_choice]
            reward = B * m / (n_i + 1 + h)
            total_reward += reward
        payoffs[my_choice] = total_reward / num_simulations
    
    results[scheme] = payoffs

# Plotting
x = np.arange(len(options))
bar_width = 0.2

plt.figure(figsize=(12, 6))

for i, scheme in enumerate(schemes):
    plt.bar(x + i * bar_width, results[scheme], width=bar_width, label=scheme.capitalize())

plt.xticks(x + bar_width * (len(schemes) - 1) / 2, [f"Opt {i}" for i in range(len(options))])
plt.ylabel("Expected Payoff")
plt.title("Expected Payoffs by Option and Weighting Scheme")
plt.legend()
plt.tight_layout()
plt.show()

# %%
import random
import numpy as np
import matplotlib.pyplot as plt
import ipywidgets as widgets
from IPython.display import display

# Game setup: (multiplier, inhabitants)
options = [
    (10, 1), (80, 6), (37, 3), (17, 1), (31, 2),
    (90, 10), (50, 4), (20, 2), (73, 4), (89, 8)
]
B = 1
num_simulations = 5000

# Weighting function
def get_weights(scheme):
    scores = []
    for m, h in options:
        r = m / (h + 1)
        if scheme == "uniform":
            scores.append(1)
        elif scheme == "linear":
            scores.append(r)
        elif scheme == "quadratic":
            scores.append(r**2)
        elif scheme == "exponential":
            scores.append(np.exp(r))
    total = sum(scores)
    return [s / total for s in scores]

# Simulation function
def simulate(num_players, scheme):
    weights = get_weights(scheme)
    payoffs = np.zeros(len(options))

    for my_choice in range(len(options)):
        total_reward = 0
        for _ in range(num_simulations):
            others = random.choices(range(len(options)), weights=weights, k=num_players - 1)
            n_i = others.count(my_choice)
            m, h = options[my_choice]
            reward = B * m / (n_i + 1 + h)
            total_reward += reward
        payoffs[my_choice] = total_reward / num_simulations
    return payoffs

# Plotting function
def plot_payoffs(num_players, scheme):
    payoffs = simulate(num_players, scheme)
    x = np.arange(len(options))
    plt.figure(figsize=(10, 5))
    bars = plt.bar(x, payoffs, color="skyblue")
    best = np.argmax(payoffs)
    bars[best].set_color("orange")

    plt.xticks(x, [f"Opt {i}" for i in x])
    plt.ylabel("Expected Payoff")
    plt.title(f"Expected Payoffs (Players: {num_players}, Scheme: {scheme})")
    plt.ylim(0, max(payoffs) * 1.2)
    plt.grid(True, axis='y')
    plt.show()

# Interactive controls
players_slider = widgets.IntSlider(value=10, min=2, max=50, step=1, description='Players:')
scheme_dropdown = widgets.Dropdown(
    options=['uniform', 'linear', 'quadratic', 'exponential'],
    value='linear',
    description='Weighting:'
)

ui = widgets.HBox([players_slider, scheme_dropdown])
out = widgets.interactive_output(plot_payoffs, {
    'num_players': players_slider,
    'scheme': scheme_dropdown
})

display(ui, out)
# Out:
# ...
# Output()

# %%
import random
import numpy as np

options = [
    (10, 1), (80, 6), (37, 3), (17, 1), (31, 2),
    (90, 10), (50, 4), (20, 2), (73, 4), (89, 8)
]

base_reward = 10_000
secondary_cost = 50_000
num_players = 10
num_simulations = 5000

# Weighted preferences: linear attractiveness
def get_weights():
    attractiveness = [m / (h + 1) for m, h in options]
    total = sum(attractiveness)
    return [a / total for a in attractiveness]

weights = get_weights()
results = []

# Try all primary-only strategies
for i in range(len(options)):
    total = 0
    for _ in range(num_simulations):
        others = random.choices(range(len(options)), weights=weights, k=num_players - 1)
        n_i = others.count(i)
        m, h = options[i]
        reward = base_reward * m / (n_i + 1 + h)
        total += reward
    avg_payoff = total / num_simulations
    results.append((f"Primary only: Option {i}", avg_payoff))

# Try all primary + secondary strategies
for i in range(len(options)):
    for j in range(len(options)):
        if i == j:
            continue
        total = 0
        for _ in range(num_simulations):
            others = random.choices(range(len(options)), weights=weights, k=num_players - 1)
            n_i = others.count(i)
            n_j = others.count(j)
            m_i, h_i = options[i]
            m_j, h_j = options[j]
            reward_i = base_reward * m_i / (n_i + 1 + h_i)
            reward_j = base_reward * m_j / (n_j + 1 + h_j)
            total += reward_i + reward_j - secondary_cost
        avg_payoff = total / num_simulations
        results.append((f"Primary {i} + Secondary {j}", avg_payoff))

# Sort by highest expected payoff
results.sort(key=lambda x: x[1], reverse=True)

# Show top results
for strategy, payoff in results[:10]:
    print(f"{strategy:<30} → Expected Payoff: {payoff:,.2f}")
# Out:
# Primary 1 + Secondary 8        → Expected Payoff: 167,492.52
# Primary 8 + Secondary 1        → Expected Payoff: 167,256.34
# Primary 8 + Secondary 9        → Expected Payoff: 157,578.25
# Primary 9 + Secondary 8        → Expected Payoff: 157,497.14
# Primary 6 + Secondary 8        → Expected Payoff: 153,595.68
# Primary 8 + Secondary 6        → Expected Payoff: 153,299.40
# Primary 8 + Secondary 4        → Expected Payoff: 148,859.63
# Primary 4 + Secondary 8        → Expected Payoff: 148,785.10
# Primary 8 + Secondary 2        → Expected Payoff: 145,929.09
# Primary 2 + Secondary 8        → Expected Payoff: 144,704.87

# %%
import random
import numpy as np

# Setup: (multiplier, inhabitants)
options = [
    (10, 1), (80, 6), (37, 3), (17, 1), (31, 2),
    (90, 10), (50, 4), (20, 2), (73, 4), (89, 8)
]

base_reward = 10_000
secondary_cost = 50_000
num_players = 10
num_simulations = 5000

# Exponential weighting based on attractiveness
def get_exp_weights():
    scores = [np.exp(m / (h + 1)) for m, h in options]
    total = sum(scores)
    return [s / total for s in scores]

weights = get_exp_weights()
results = []

# Primary-only choices
for i in range(len(options)):
    total = 0
    for _ in range(num_simulations):
        others = random.choices(range(len(options)), weights=weights, k=num_players - 1)
        n_i = others.count(i)
        m, h = options[i]
        reward = base_reward * m / (n_i + 1 + h)
        total += reward
    avg_payoff = total / num_simulations
    results.append((f"Primary only: Option {i}", avg_payoff))

# Primary + secondary choices
for i in range(len(options)):
    for j in range(len(options)):
        if i == j:
            continue
        total = 0
        for _ in range(num_simulations):
            others = random.choices(range(len(options)), weights=weights, k=num_players - 1)
            n_i = others.count(i)
            n_j = others.count(j)
            m_i, h_i = options[i]
            m_j, h_j = options[j]
            reward_i = base_reward * m_i / (n_i + 1 + h_i)
            reward_j = base_reward * m_j / (n_j + 1 + h_j)
            total += reward_i + reward_j - secondary_cost
        avg_payoff = total / num_simulations
        results.append((f"Primary {i} + Secondary {j}", avg_payoff))

# Sort results by expected payoff
results.sort(key=lambda x: x[1], reverse=True)

# Print top strategies
print("\nTop 10 Strategies (Exponential Weighting):\n")
for strategy, payoff in results[:10]:
    print(f"{strategy:<35} → Expected Payoff: {payoff:,.2f}")
# Out:
# Top 10 Strategies (Exponential Weighting):
#
# Primary 1 + Secondary 4             → Expected Payoff: 160,002.53
# Primary 4 + Secondary 1             → Expected Payoff: 159,729.19
# Primary 6 + Secondary 1             → Expected Payoff: 158,110.74
# Primary 1 + Secondary 6             → Expected Payoff: 158,064.18
# Primary 1 + Secondary 9             → Expected Payoff: 157,614.11
# Primary 9 + Secondary 1             → Expected Payoff: 157,377.28
# Primary 2 + Secondary 1             → Expected Payoff: 151,440.64
# Primary 1 + Secondary 2             → Expected Payoff: 151,036.44
# Primary 6 + Secondary 4             → Expected Payoff: 149,023.48
# Primary 4 + Secondary 6             → Expected Payoff: 148,964.58

# %%
import random
import numpy as np

options = [
    (10, 1), (80, 6), (37, 3), (17, 1), (31, 2),
    (90, 10), (50, 4), (20, 2), (73, 4), (89, 8)
]

base_reward = 10_000
secondary_cost = 50_000
num_players = 10
num_simulations = 5000
rational_fraction = 0.4  # e.g., 40% of population is strategic

# Compute exponential weights
def get_exp_weights():
    scores = [np.exp(m / (h + 1)) for m, h in options]
    total = sum(scores)
    return [s / total for s in scores]

# Get top-k options based on payoff (used by strategic players)
def get_top_k_strategies(k=3):
    weights = get_exp_weights()
    strategy_scores = []
    for i in range(len(options)):
        total = 0
        for _ in range(1000):
            others = random.choices(range(len(options)), weights=weights, k=num_players - 1)
            n_i = others.count(i)
            m, h = options[i]
            reward = base_reward * m / (n_i + 1 + h)
            total += reward
        avg = total / 1000
        strategy_scores.append((i, avg))
    strategy_scores.sort(key=lambda x: x[1], reverse=True)
    top_k = [s[0] for s in strategy_scores[:k]]
    return top_k

# Simulate under blended population model
def simulate_payoff(primary, secondary=None):
    weights = get_exp_weights()
    top_k = get_top_k_strategies(k=3)

    total = 0
    for _ in range(num_simulations):
        choices = []
        for _ in range(num_players - 1):
            if random.random() < rational_fraction:
                # Rational player: chooses from top k
                choice = random.choice(top_k)
            else:
                # Heuristic player: uses exponential weighting
                choice = random.choices(range(len(options)), weights=weights, k=1)[0]
            choices.append(choice)

        n_i = choices.count(primary)
        m_i, h_i = options[primary]
        reward = base_reward * m_i / (n_i + 1 + h_i)

        if secondary is not None:
            n_j = choices.count(secondary)
            m_j, h_j = options[secondary]
            reward += base_reward * m_j / (n_j + 1 + h_j)
            reward -= secondary_cost

        total += reward

    return total / num_simulations

# Try all strategies
results = []
for i in range(len(options)):
    payoff = simulate_payoff(i)
    results.append((f"Primary only: {i}", payoff))

for i in range(len(options)):
    for j in range(len(options)):
        if i != j:
            payoff = simulate_payoff(i, j)
            results.append((f"Primary {i} + Secondary {j}", payoff))

# Sort and show top strategies
results.sort(key=lambda x: x[1], reverse=True)
print(f"\nTop 10 strategies assuming {int(rational_fraction*100)}% rational players:\n")
for strategy, payoff in results[:10]:
    print(f"{strategy:<35} → Expected Payoff: {payoff:,.2f}")
# Out:
# Top 10 strategies assuming 40% rational players:
#
# Primary 9 + Secondary 1             → Expected Payoff: 145,300.21
# Primary 1 + Secondary 9             → Expected Payoff: 145,096.80
# Primary 2 + Secondary 9             → Expected Payoff: 140,583.83
# Primary 9 + Secondary 2             → Expected Payoff: 140,561.21
# Primary 2 + Secondary 1             → Expected Payoff: 139,095.46
# Primary 1 + Secondary 2             → Expected Payoff: 138,644.71
# Primary 9 + Secondary 3             → Expected Payoff: 133,161.00
# Primary 3 + Secondary 9             → Expected Payoff: 133,119.04
# Primary 1 + Secondary 3             → Expected Payoff: 131,540.47
# Primary 3 + Secondary 1             → Expected Payoff: 131,274.47

# %%
import random
import numpy as np
from tqdm import tqdm

# Setup
options = [
    (10, 1), (80, 6), (37, 3), (17, 1), (31, 2),
    (90, 10), (50, 4), (20, 2), (73, 4), (89, 8)
]
base_reward = 10_000
secondary_cost = 50_000
num_players = 10
num_simulations = 2000  # reduce to speed up, increase for more accuracy

# Exponential attractiveness weights
def get_exp_weights():
    scores = [np.exp(m / (h + 1)) for m, h in options]
    total = sum(scores)
    return [s / total for s in scores]

# Determine top-k strategic options under default (exponential) heuristic
def get_top_k_strategies(k=3):
    weights = get_exp_weights()
    strategy_scores = []
    for i in range(len(options)):
        total = 0
        for _ in range(500):
            others = random.choices(range(len(options)), weights=weights, k=num_players - 1)
            n_i = others.count(i)
            m, h = options[i]
            reward = base_reward * m / (n_i + 1 + h)
            total += reward
        avg = total / 500
        strategy_scores.append((i, avg))
    strategy_scores.sort(key=lambda x: x[1], reverse=True)
    return [s[0] for s in strategy_scores[:k]]

# Simulate given rational fraction and strategy
def simulate_payoff(primary, secondary, rational_fraction):
    weights = get_exp_weights()
    top_k = get_top_k_strategies(k=3)

    total = 0
    for _ in range(num_simulations):
        choices = []
        for _ in range(num_players - 1):
            if random.random() < rational_fraction:
                choice = random.choice(top_k)
            else:
                choice = random.choices(range(len(options)), weights=weights, k=1)[0]
            choices.append(choice)

        n_i = choices.count(primary)
        m_i, h_i = options[primary]
        reward = base_reward * m_i / (n_i + 1 + h_i)

        if secondary is not None:
            n_j = choices.count(secondary)
            m_j, h_j = options[secondary]
            reward += base_reward * m_j / (n_j + 1 + h_j)
            reward -= secondary_cost

        total += reward

    return total / num_simulations

# Main loop
rationalities = [r / 100 for r in range(25, 100, 5)]
best_payoffs = []

print("Simulating across rationality levels...\n")
for r in tqdm(rationalities):
    best_strategy = None
    best_payoff = -np.inf

    # Try all strategies
    for i in range(len(options)):
        payoff = simulate_payoff(i, None, r)
        if payoff > best_payoff:
            best_payoff = payoff
            best_strategy = f"Primary {i}"

    for i in range(len(options)):
        for j in range(len(options)):
            if i != j:
                payoff = simulate_payoff(i, j, r)
                if payoff > best_payoff:
                    best_payoff = payoff
                    best_strategy = f"Primary {i} + Secondary {j}"

    best_payoffs.append(best_payoff)
    print(f"Rationality {int(r*100)}% → Best: {best_strategy:<30} → Payoff: {best_payoff:,.2f}")

# Compute uniform weighted mean
mean_best_payoff = np.mean(best_payoffs)
print(f"\n✅ Weighted Mean Expected Payoff (Uniform) = {mean_best_payoff:,.2f}")
# Out:
# Simulating across rationality levels...
#   7%|███▌                                                  | 1/15 [00:06<01:31,  6.52s/it]
# Rationality 25% → Best: Primary 9 + Secondary 1        → Payoff: 149,295.26
#  13%|███████▏                                              | 2/15 [00:12<01:17,  5.93s/it]
# Rationality 30% → Best: Primary 9 + Secondary 1        → Payoff: 148,535.47
#  20%|██████████▊                                           | 3/15 [00:17<01:07,  5.61s/it]
# Rationality 35% → Best: Primary 1 + Secondary 9        → Payoff: 146,750.67
#  27%|██████████████▍                                       | 4/15 [00:22<01:00,  5.48s/it]
# Rationality 40% → Best: Primary 9 + Secondary 1        → Payoff: 145,300.90
#  33%|██████████████████                                    | 5/15 [00:27<00:53,  5.30s/it]
# Rationality 45% → Best: Primary 1 + Secondary 9        → Payoff: 144,011.11
#  40%|█████████████████████▌                                | 6/15 [00:32<00:46,  5.15s/it]
# ...

# %%
import random
import numpy as np
from tqdm import tqdm

# Setup
options = [
    (10, 1), (80, 6), (37, 3), (17, 1), (31, 2),
    (90, 10), (50, 4), (20, 2), (73, 4), (89, 8)
]
base_reward = 10_000
secondary_cost = 50_000
num_players = 10
num_simulations = 1500  # for speed
rationalities = [r / 100 for r in range(25, 100, 5)]

# Exponential attractiveness weights
def get_exp_weights():
    scores = [np.exp(m / (h + 1)) for m, h in options]
    total = sum(scores)
    return [s / total for s in scores]

# Top-k strategies under exponential weighting (used by rational players)
def get_top_k_strategies(k=3):
    weights = get_exp_weights()
    scores = []
    for i in range(len(options)):
        total = 0
        for _ in range(500):
            others = random.choices(range(len(options)), weights=weights, k=num_players - 1)
            n_i = others.count(i)
            m, h = options[i]
            reward = base_reward * m / (n_i + 1 + h)
            total += reward
        scores.append((i, total / 500))
    scores.sort(key=lambda x: x[1], reverse=True)
    return [i for i, _ in scores[:k]]

# Simulate a strategy under a rationality level
def simulate_strategy(primary, secondary, rational_fraction):
    weights = get_exp_weights()
    top_k = get_top_k_strategies(k=3)

    total = 0
    for _ in range(num_simulations):
        choices = []
        for _ in range(num_players - 1):
            if random.random() < rational_fraction:
                choice = random.choice(top_k)
            else:
                choice = random.choices(range(len(options)), weights=weights)[0]
            choices.append(choice)

        n_i = choices.count(primary)
        m_i, h_i = options[primary]
        reward = base_reward * m_i / (n_i + 1 + h_i)

        if secondary is not None:
            n_j = choices.count(secondary)
            m_j, h_j = options[secondary]
            reward += base_reward * m_j / (n_j + 1 + h_j)
            reward -= secondary_cost

        total += reward

    return total / num_simulations

# Build all possible strategies
all_strategies = [(i, None) for i in range(len(options))]
all_strategies += [(i, j) for i in range(len(options)) for j in range(len(options)) if i != j]

# Track average expected value per strategy
strategy_scores = []

print("Evaluating all strategies across rationality levels...\n")
for primary, secondary in tqdm(all_strategies):
    rational_payoffs = []
    for r in rationalities:
        payoff = simulate_strategy(primary, secondary, r)
        rational_payoffs.append(payoff)
    mean_payoff = np.mean(rational_payoffs)
    label = f"Primary {primary}" if secondary is None else f"Primary {primary} + Secondary {secondary}"
    strategy_scores.append((label, mean_payoff))

# Sort and show best overall
strategy_scores.sort(key=lambda x: x[1], reverse=True)

print("\nTop strategies by mean payoff across rationality levels:\n")
for label, avg in strategy_scores[:10]:
    print(f"{label:<35} → Mean Expected Payoff: {avg:,.2f}")

best_strategy = strategy_scores[0]
print(f"\n✅ Best Overall Strategy = {best_strategy[0]} with Mean Payoff = {best_strategy[1]:,.2f}")
# Out:
# Evaluating all strategies across rationality levels...
# 100%|███████████████████████████████████████████████████| 100/100 [01:04<00:00,  1.54it/s]
# Top strategies by mean payoff across rationality levels:
#
# Primary 9 + Secondary 8             → Mean Expected Payoff: 143,136.66
# Primary 8 + Secondary 9             → Mean Expected Payoff: 141,945.41
# Primary 9 + Secondary 2             → Mean Expected Payoff: 140,796.48
# Primary 1 + Secondary 9             → Mean Expected Payoff: 140,179.41
# Primary 2 + Secondary 9             → Mean Expected Payoff: 139,639.59
# Primary 9 + Secondary 1             → Mean Expected Payoff: 138,803.55
# Primary 2 + Secondary 8             → Mean Expected Payoff: 136,797.12
# Primary 8 + Secondary 2             → Mean Expected Payoff: 136,736.63
# Primary 8 + Secondary 1             → Mean Expected Payoff: 136,098.85
# Primary 1 + Secondary 8             → Mean Expected Payoff: 135,975.98
#
# ...

# %%
import random
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
from tqdm import tqdm
import itertools

# Game setup
options = [
    (10, 1), (80, 6), (37, 3), (17, 1), (31, 2),
    (90, 10), (50, 4), (20, 2), (73, 4), (89, 8)
]
base_reward = 10_000
secondary_cost = 50_000
num_players = 10
num_simulations = 1000
rationalities = [r / 100 for r in range(25, 100, 5)]

# Generate strategy labels
primary_only = [(i, None) for i in range(len(options))]
primary_secondary = [(i, j) for i in range(len(options)) for j in range(len(options)) if i != j]
all_strategies = primary_only + primary_secondary
strategy_labels = [f"P{i}" if j is None else f"P{i}+S{j}" for i, j in all_strategies]

# Get exponential weights
def get_exp_weights():
    scores = [np.exp(m / (h + 1)) for m, h in options]
    total = sum(scores)
    return [s / total for s in scores]

# Get top-k best options under exponential weights
def get_top_k_strategies(k=3):
    weights = get_exp_weights()
    scores = []
    for i in range(len(options)):
        total = 0
        for _ in range(300):
            others = random.choices(range(len(options)), weights=weights, k=num_players - 1)
            n_i = others.count(i)
            m, h = options[i]
            reward = base_reward * m / (n_i + 1 + h)
            total += reward
        scores.append((i, total / 300))
    scores.sort(key=lambda x: x[1], reverse=True)
    return [i for i, _ in scores[:k]]

# Simulate one strategy at a given rationality level
def simulate_strategy(primary, secondary, rational_fraction):
    weights = get_exp_weights()
    top_k = get_top_k_strategies(k=3)
    total = 0

    for _ in range(num_simulations):
        choices = []
        for _ in range(num_players - 1):
            if random.random() < rational_fraction:
                choice = random.choice(top_k)
            else:
                choice = random.choices(range(len(options)), weights=weights)[0]
            choices.append(choice)

        n_i = choices.count(primary)
        m_i, h_i = options[primary]
        reward = base_reward * m_i / (n_i + 1 + h_i)

        if secondary is not None:
            n_j = choices.count(secondary)
            m_j, h_j = options[secondary]
            reward += base_reward * m_j / (n_j + 1 + h_j)
            reward -= secondary_cost

        total += reward

    return total / num_simulations

# Run all simulations
payoff_matrix = pd.DataFrame(index=strategy_labels, columns=[int(r*100) for r in rationalities], dtype=float)
strategy_best_count = {label: 0 for label in strategy_labels}

for idx, (primary, secondary) in tqdm(enumerate(all_strategies), total=len(all_strategies)):
    label = strategy_labels[idx]
    for r in rationalities:
        payoff = simulate_strategy(primary, secondary, r)
        payoff_matrix.loc[label, int(r*100)] = payoff

# Track which strategy is best at each rationality level
for r in payoff_matrix.columns:
    best_strategy = payoff_matrix[r].idxmax()
    strategy_best_count[best_strategy] += 1

# Heatmap
plt.figure(figsize=(18, 10))
sns.heatmap(payoff_matrix.astype(float), annot=False, cmap="viridis", linewidths=0.5, linecolor='gray')
plt.title("Expected Payoff Heatmap (Strategy vs Rationality %)")
plt.xlabel("Rationality Level (%)")
plt.ylabel("Strategy")
plt.tight_layout()
plt.show()

# Strategy stability barplot
stability_df = pd.DataFrame({
    "Strategy": list(strategy_best_count.keys()),
    "Best Count": list(strategy_best_count.values())
}).sort_values("Best Count", ascending=False)

plt.figure(figsize=(14, 6))
sns.barplot(data=stability_df, x="Strategy", y="Best Count", palette="deep")
plt.title("Strategy Stability: # of Times Best Across Rationality Levels")
plt.xlabel("Strategy")
plt.ylabel("# of Times Best")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# 100%|███████████████████████████████████████████████████| 100/100 [00:41<00:00,  2.40it/s]
# /var/folders/cn/yvfyzgz910bghnld237rzj3h0000gn/T/ipykernel_48554/1098010105.py:108: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=stability_df, x="Strategy", y="Best Count", palette="deep")

# %%
stability_df
# Out:
#    Strategy  Best Count
# 92    P9+S1           5
# 99    P9+S8           4
# 71    P6+S8           2
# 27    P1+S9           2
# 90    P8+S9           1
# ..      ...         ...
# 95    P9+S4           0
# 96    P9+S5           0
# 97    P9+S6           0
# 98    P9+S7           0
# 1        P1           0
#
# [100 rows x 2 columns]

# %%
payoff_matrix
# Out:
#                   25             30             35             40  \
# P0      50000.000000   50000.000000   50000.000000   50000.000000
# P1     101411.111111   99346.897547   98116.998557   96225.425685
# P2      92000.500000   92111.500000   92074.500000   91982.000000
# P3      84546.666667   84745.000000   84801.666667   84716.666667
# P4      84464.666667   82004.964286   79142.630952   76737.178571
# ...              ...            ...            ...            ...
# P9+S4  132631.663059  129707.218975  126961.976551  125879.524170
# P9+S5  130189.545455  121897.829004  130088.707071  130173.515152
# P9+S6  140026.661061  133702.282828  132223.251082  130321.603175
# P9+S7  114995.000000  114929.373737  115098.797980  104404.661117
# P9+S8  114545.609862  117312.648490  120384.190643  122854.171745
#
#                   45             50             55             60  \
# P0      49983.333333   50000.000000   50000.000000   50000.000000
# ...

# %%
np.argmax(payoff_matrix.mean(axis=0))
# Out:
# 14

# %%
payoff_matrix.mean(axis=1)
row_means = payoff_matrix.mean(axis=1)

# Get indices that would sort the row means in descending order
sorted_indices = np.argsort(row_means)[::-1]

# Sort the row means using these indices
sorted_row_means = row_means.iloc[sorted_indices]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[37], line 11
#       8 sorted_row_means = row_means.iloc[sorted_indices]
#      10 # If you also want to sort the original matrix accordingly
# ---> 11 sorted_payoff_matrix = payoff_matrix[sorted_indices]
#
# File ~/opt/anaconda3/envs/clean_env/lib/python3.9/site-packages/pandas/core/frame.py:3813, in DataFrame.__getitem__(self, key)
#    3811     if is_iterator(key):
#    3812         key = list(key)
# -> 3813     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3815 # take() does not accept boolean indexers
#    3816 if getattr(indexer, "dtype", None) == bool:
#
# File ~/opt/anaconda3/envs/clean_env/lib/python3.9/site-packages/pandas/core/indexes/base.py:6070, in Index._get_indexer_strict(self, key, axis_name)
#    6067 else:
#    6068     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# ...

# %%
# Calculate the row means
row_means = payoff_matrix.mean(axis=1)

# Sort the row means in descending order
sorted_row_means = row_means.sort_values(ascending=False)

# %%
sorted_row_means.head(10)
# Out:
# P8+S9    143140.716095
# P9+S8    143130.847521
# P9+S1    140005.164802
# P9+S2    139452.671624
# P1+S9    139441.405979
# P2+S9    137486.652695
# P8+S2    136716.995057
# P2+S8    136592.861794
# P1+S8    136107.552346
# P8+S1    135954.029056
# dtype: float64

# %%
data = pd.read_csv("/Users/evangray/Desktop/Projects/prosperity/prosperity-3/Data Logs/Round 3/d3dab92a-3183-4454-add8-b614e497477d.csv", delimiter=";")

# %%
data
# Out:
#        day  timestamp                      product  bid_price_1  bid_volume_1  \
# 0        2          0               PICNIC_BASKET2      30094.0          16.0
# 1        2          0   VOLCANIC_ROCK_VOUCHER_9750        469.0          16.0
# 2        2          0             RAINFOREST_RESIN       9992.0          33.0
# 3        2          0   VOLCANIC_ROCK_VOUCHER_9500        718.0          16.0
# 4        2          0                VOLCANIC_ROCK      10218.0         148.0
# ...    ...        ...                          ...          ...           ...
# 13995    2      99900                    SQUID_INK       1787.0          28.0
# 13996    2      99900                         JAMS       6543.0         274.0
# 13997    2      99900  VOLCANIC_ROCK_VOUCHER_10000        182.0          18.0
# 13998    2      99900  VOLCANIC_ROCK_VOUCHER_10250         39.0          18.0
# 13999    2      99900                VOLCANIC_ROCK      10155.0         130.0
#
# ...

# %%
data[data["product"] == "PICNIC_BASKET1"]
# Out:
#        day  timestamp         product  bid_price_1  bid_volume_1  bid_price_2  \
# 13       2          0  PICNIC_BASKET1      58702.0          16.0      58701.0
# 18       2        100  PICNIC_BASKET1      58705.0           2.0      58704.0
# 37       2        200  PICNIC_BASKET1      58710.0          14.0      58709.0
# 42       2        300  PICNIC_BASKET1      58712.0           1.0      58711.0
# 64       2        400  PICNIC_BASKET1      58710.0          19.0      58709.0
# ...    ...        ...             ...          ...           ...          ...
# 13942    2      99500  PICNIC_BASKET1      58898.0          17.0      58897.0
# 13950    2      99600  PICNIC_BASKET1      58896.0           2.0      58895.0
# 13959    2      99700  PICNIC_BASKET1      58899.0          44.0          NaN
# 13984    2      99800  PICNIC_BASKET1      58904.0           5.0      58900.0
# 13991    2      99900  PICNIC_BASKET1      58892.0           1.0      58891.0
#
# ...

# %%
def best_ask()

# %%
data[data["product"] == "CROISSANTS"]
# Out:
#        day  timestamp     product  bid_price_1  bid_volume_1  bid_price_2  \
# 9        2          0  CROISSANTS       4265.0          61.0       4264.0
# 17       2        100  CROISSANTS       4265.0          50.0       4264.0
# 40       2        200  CROISSANTS       4265.0         118.0          NaN
# 46       2        300  CROISSANTS       4265.0         110.0          NaN
# 57       2        400  CROISSANTS       4266.0          47.0       4265.0
# ...    ...        ...         ...          ...           ...          ...
# 13940    2      99500  CROISSANTS       4263.0         113.0          NaN
# 13948    2      99600  CROISSANTS       4264.0          39.0       4263.0
# 13966    2      99700  CROISSANTS       4263.0         109.0          NaN
# 13974    2      99800  CROISSANTS       4264.0          49.0       4263.0
# 13989    2      99900  CROISSANTS       4262.0         135.0          NaN
#
#        bid_volume_2  bid_price_3  bid_volume_3  ask_price_1  ask_volume_1  \
# ...

# %% [markdown]
# **PICNIC_BASKET1**\
# 6 CROISSANTS\
# 3 JAMS\
# 1 DJMEMBES

# %% [markdown]
# **PICNIC_BASKET2**\
# 4 CROISSANTS\
# 2 JAMS
